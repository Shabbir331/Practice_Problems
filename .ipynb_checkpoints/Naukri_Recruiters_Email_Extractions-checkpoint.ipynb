# %%
from selenium import webdriver
import time 
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
driver = webdriver.Chrome(executable_path=r'chromedriver.exe')
driver.get('https://www.naukri.com/nlogin/logout')
# Username & Password
driver.find_element(By.ID, "usernameField").send_keys("")
driver.find_element(By.ID, "passwordField").send_keys("")
driver.find_element(By.ID, "usernameField").click()
driver.find_element(By.CSS_SELECTOR, ".waves-effect").click()
time.sleep(5)
driver.get('https://www.naukri.com/mnjuser/inbox')
time.sleep(10)
# driver.find_element(By.LINK_TEXT, "APPLY").click()
driver.find_element(By.CSS_SELECTOR, ".row:nth-child(2) .txt > .fs15").click()
time.sleep(5)
html_source = driver.page_source

# %%
emails=[]
from bs4 import BeautifulSoup
for i in range(1,100):    
        driver.find_element(By.CSS_SELECTOR, ".inbox-list").click()
        time.sleep(3)
        element = driver.find_element(By.CSS_SELECTOR, ".row:nth-child("+str(i)+") > .col > .blue-text")
        actions = ActionChains(driver)
        actions.move_to_element(element).click_and_hold().perform()
        time.sleep(3)
        html_source = driver.page_source
        soup =BeautifulSoup(html_source,'lxml')
        for link in soup.find_all('a')[110:111]:     
            if "@" in link.get_text('href'):
                emails.append(link.get_text('href'))
                print(i,link.get_text('href'))
# Out:
# 1 ct23@convate.com
# 21 ct23@convate.com
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-3-df40543b2783> in <module>
#       4         driver.find_element(By.CSS_SELECTOR, ".inbox-list").click()
#       5         time.sleep(3)
# ----> 6         element = driver.find_element(By.CSS_SELECTOR, ".row:nth-child("+str(i)+") > .col > .blue-text")
#       7         actions = ActionChains(driver)
#       8         actions.move_to_element(element).click_and_hold().perform()
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".row:nth-child(70) > .col > .blue-text"}
#   (Session info: chrome=79.0.3945.88)

# %%
import pandas as pd
pd.set_option('display.max_columns', None)  
pd.set_option('display.max_rows', None)
pd.set_option('display.width', 2000)
pd.DataFrame(list(set(emails)))
# Out:
#                                       0
# 0        nsheth@integrative-systems.com
# 1                   hrd.vedha@gmail.com
# 2                      gc04@glocons.com
# 3               pinki@placementzone.com
# 4        Aashwini_Kanade@persistent.com
# 5            sunitha.george@xoriant.com
# 6    support@peoplepoweredsolutions.com
# 7              prachi.naik@sterlite.com
# 8            perfectplacerdel@gmail.com
# 9            urvashi@montekservices.com
# 10               rajesh.y@paraminfo.com
# 11           shivsingh@pnrtechnology.in
# 12          sayali.a@montekservices.com
# 13                   jobs@jobsquare.com
# 14       akshay.chavan@enterprisedb.com
# 15    jkoshy@allegisglobalsolutions.com
# 16           aditi.sharma@incedoinc.com
# 17  sachitanand.gudup@springernature...
# 18          ext-Karishma.singh@here.com
# 19                     veni@enejobs.com
# 20              vividh.dass@nagarro.com
# 21          vineet.kakkar@damcosoft.com
# 22            priyanka.shinde@nityo.com
# 23              pradha@mindpooltech.com
# 24         padma.ed@joyitconsulting.com
# 25                hirepundit1@gmail.com
# 26            Recruiter3@saisystems.com
# 27                naukri004@convate.com
# 28             vidyashree.gkc@gmail.com
# 29                jobs@noblecareerz.com
# 30                     jobs@cropdata.in
# 31           swati@exelonconsulting.com
# 32        Devaraj@glaubentechnology.com
# 33                 roy.purba@arminus.in
# 34                  chandan@teamkcs.com
# 35               eswaran@fourentech.com
# 36                   rupa.b@pramati.com
# 37             saheli@placementzone.com
# 38         heena.ruchwani@bizmetric.com
